# %% [markdown]
# #### Popular Encoders
#
# 1. OpenAI Text Embeddings
#
#     - `text-embedding-3-large` - 3072-Dimensional vectors
#
#     - `text-embedding-3-small` - 1536-Dimensional vectors
#
# 2. Gemini Embeddings - `text-embedding-004` - 768-Dimensioinal vectors
#
# 3. HuggingFace all-miniLM-L6-v2 - `all-MiniLM-L6-v2` - 384-Dimensional vectors

# %% [markdown]
# #### Popular Vector Stores
#
# -  Open Source
#
#     - Chroma
#
#     - Qdrant
#
#     - FAISS [Facebook AI Similarity Search / Meta AI Similarity Search]
#
# - Paid & Scalable
#
#     - Pinecone
#
#     - Weaviate
#
# - Mainstream DB
#
#     - Postgres
#
#     - Mongo
#
#     - Elastic
